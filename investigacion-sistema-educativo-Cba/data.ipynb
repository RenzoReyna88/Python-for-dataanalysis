# %% [markdown]
# ### Investigación sobre las condiciones de la población educativa para Escuelas nivel primario - secundario del Departamento Totoral, Província de Córdoba.
# ---
# #### Datos extraidos del sitio Oficial del Gobierno de Córdoba:
# ##### Fuente: https://www.cba.gov.ar/padron-de-escuelas-provinciales-educacion/

# %% [markdown]
# #### Autor:
# ##### Renzo Gerardo Reyna
# ##### analista de datos | Desarrollador Python
#
# Contacto:
#
# - desarrollador.sarmientino@gmail.com
# - DS.techsolutions@outlook.com
#
# - https://www.desarrolladorsarmientino.com/

# %% [markdown]
# !Gráficos-primaria/sobreedad.png

# %%
# INVOCAR HERRAMIENTAS PARA PROCESAR LOS DATOS

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ### Procesamiento de datos para escuelas del nivel Primario
# ---

# %%
# Lectura de archivos CSV para nivel primario
leer_archivo_matriculados_primaria= pd.read_csv("datos-nivel-primario/alumnos_matriculados_primario_1998-2021.csv", sep=';')

leer_archivo_matriculados_primaria_segun_genero= pd.read_csv("datos-nivel-primario/alumnos_matriculados_primario_segun_genero_1998-2021.csv", sep=';')

leer_archivo_repitentes_primaria= pd.read_csv("datos-nivel-primario/alumnos_repitentes_primario_1998-2021.csv", sep=';')

leer_archivo_sobredad_primaria= pd.read_csv("datos-nivel-primario/alumnos_con_sobredad_primario_1998-2021.csv", sep=';')

# %%
# Crear Dataframe para alumnos matriculados de escuelas primarias en la Prov. de Córdoba
matriculados_primaria= pd.DataFrame(leer_archivo_matriculados_primaria)

matriculados_primaria
# Out:
#                    Departamento    1998    1999    2000    2001    2002  \
# 0               Total Provincia  365357  368976  371116  368857  370407
# 1                   Calamuchita    5354    5429    5439    5375    5477
# 2                       Capital  149286  150343  150953  150664  150179
# 3                         Col�n   21410   22365   23573   23739   24346
# 4                  Cruz del Eje    7361    7448    7546    7656    7829
# 5                  General Roca    4511    4441    4327    4249    4205
# 6            General San Mart�n   13588   13790   13770   13639   13697
# 7                      Ischil�n    4100    4182    4185    4215    4247
# 8                 Ju�rez Celman    6578    6701    6767    6648    6612
# 9                 Marcos Ju�rez   11114   11137   11069   11048   11065
# 10                        Minas     658     656     663     693     712
# 11                        Pocho     650     670     666     627     647
# ...

# %%
matriculados_primaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Departamento  27 non-null     object
#  1   1998          27 non-null     int64
#  2   1999          27 non-null     int64
#  3   2000          27 non-null     int64
#  4   2001          27 non-null     int64
#  5   2002          27 non-null     int64
#  6   2003          27 non-null     int64
#  7   2004          27 non-null     int64
#  8   2005          27 non-null     int64
#  9   2006          27 non-null     int64
#  10  2007          27 non-null     int64
#  11  2008          27 non-null     int64
#  12  2009          27 non-null     int64
#  13  2010          27 non-null     int64
#  14  2011          27 non-null     int64
#  15  2012          27 non-null     int64
#  16  2013          27 non-null     int64
#  17  2014          27 non-null     int64
# ...

# %%
print(f'Total de valores nulos encontrados: {matriculados_primaria.isnull().sum()}')

print(f'\n Total de valores duplicados encontrados: {matriculados_primaria.duplicated().sum()}')
# Out:
# Total de valores nulos encontrados: Departamento    0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64
#
#  Total de valores duplicados encontrados: 0

# %%
matriculados_primaria.head()
# Out:
#       Departamento    1998    1999    2000    2001    2002    2003    2004  \
# 0  Total Provincia  365357  368976  371116  368857  370407  364191  362467
# 1      Calamuchita    5354    5429    5439    5375    5477    5474    5501
# 2          Capital  149286  150343  150953  150664  150179  147503  146300
# 3            Col�n   21410   22365   23573   23739   24346   24303   24716
# 4     Cruz del Eje    7361    7448    7546    7656    7829    7837    7771
#
#      2005    2006  ...    2012    2013    2014    2015    2016    2017  \
# 0  361642  351320  ...  364253  362081  361833  359001  358127  356661
# 1    5514    5614  ...    6333    6496    6683    6654    6698    6736
# 2  145570  139713  ...  144054  143355  143108  142607  142556  142132
# 3   24941   24330  ...   26967   26932   27402   27697   27686   27878
# 4    7720    6732  ...    6982    6894    6790    6596    6464    6470
#
#      2018    2019    2020    2021
# 0  355984  357841  358055  359573
# ...

# %%
# Seleccionar fila para Dpto. Totoral
Departamento_Totoral= matriculados_primaria.iloc[24]

# %% [markdown]
# ##### Según el padrón de Escuelas (2023), el Departamento Totoral cuenta con 33 Escuelas primarias de Gestión Estatal.
# ##### Fuente: https://www.cba.gov.ar/padron-de-escuelas-provinciales-educacion/

# %%
# Crear Dataframe para alumnos inscritos en escuelas primarias del Dpto. Totoral 
df_matriculados_primaria= pd.DataFrame(Departamento_Totoral)

df_matriculados_primaria_totoral= df_matriculados_primaria.T

# %%
'''Los datos en las siguientes variables representan la cantidad de alumnos de primaria incritos en el Dpto Totoral 
   para el peridodo comprendido entre el año 1998-2021'''

data_inscritos = [2188, 2193, 2173, 2171, 2253, 2229, 2213, 2199, 2179, 2162, 2104, 2102, 2159, 2151, 2120, 2085, 2078, 2009, 2008, 1987, 2035, 2019, 1984, 2012]
años = [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# Estilo de Seaborn
sns.set(style="whitegrid")

# Tamaño de la figura
plt.figure(figsize=(12, 8))

# Crear gráfico de barras
barplot = sns.barplot(x=años, y=data_inscritos, hue=años, palette='viridis', edgecolor='#2c3e50', alpha=0.8, legend=False)

# Agregar etiquetas con las cantidades de alumnos para cada barra
for i, txt in enumerate(data_inscritos):
    barplot.text(i, txt, f'{txt}', ha='center', va='bottom', fontsize=10, color='#333333')

# Configurar etiquetas y título
plt.xlabel('Año', fontsize=14, fontweight='bold')
plt.ylabel('Cantidad de alumnos inscritos', fontsize=14, fontweight='bold')
plt.title('Cantidad de alumnos del Dpto. Totoral inscritos por año - Nivel primario', fontsize=16, fontweight='bold')

# Configurar color de fondo del gráfico
plt.setp(barplot.patches, linewidth=0)

# Ajustar el color de fondo
plt.gca().set_facecolor('#ecf0f1')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

Promedio_por_años= np.mean(data_inscritos)

print(f' Promedio de alumnos de primaria inscritos en el Dpto Totoral entre el periodo 1998 - 2021: {Promedio_por_años}')
# Out:
#  Promedio de alumnos de primaria inscritos en el Dpto Totoral entre el periodo 1998 - 2021: 2117.2083333333335

# %% [markdown]
# ##### “El gráfico anterior muestra el comportamiento de los alumnos inscritos en las escuelas del Departamento de Totoral. Se puede apreciar que no hubo cambios significativos en las inscripciones hasta el período 2021.”

# %%
# Crear Dataframe para alumnos de escuelas primarias inscritos en la Provincia de Córdoba
df_matriculados_primario_segun_genero= pd.DataFrame(leer_archivo_matriculados_primaria_segun_genero)

# %%
df_matriculados_primario_segun_genero
# Out:
#                   Departamentos  Varones  Mujeres  Varones.1  Mujeres.1  \
# 0               Total Provincia   185693   179664     187747     181229
# 1                   Calamuchita     2714     2640       2803       2626
# 2                       Capital    75438    73848      76251      74092
# 3                         Col�n    10951    10459      11383      10982
# 4                  Cruz del Eje     3749     3612       3774       3674
# 5                  General Roca     2304     2207       2285       2156
# 6            General San Mart�n     6921     6667       6939       6851
# 7                      Ischil�n     2125     1975       2146       2036
# 8                 Ju�rez Celman     3369     3209       3454       3247
# 9                 Marcos Ju�rez     5682     5432       5709       5428
# 10                        Minas      346      312        336        320
# 11                        Pocho      349      301        361        309
# ...

# %%
print(f'Total de valores nulos encontrados: {df_matriculados_primario_segun_genero.isnull().sum()}')

print(f'\n Total de valores duplicados encontrados: {df_matriculados_primario_segun_genero.duplicated().sum()}')
# Out:
# Total de valores nulos encontrados: Departamentos    0
# Varones          0
# Mujeres          0
# Varones.1        0
# Mujeres.1        0
# Varones.2        0
# Mujeres.2        0
# Varones.3        0
# Mujeres.3        0
# Varones.4        0
# Mujeres.4        0
# Varones.5        0
# Mujeres.5        0
# Varones.6        0
# Mujeres.6        0
# Varones.7        0
# Mujeres.7        0
# Varones.8        0
# Mujeres.8        0
# Varones.9        0
# Mujeres.9        0
# Varones.10       0
# Mujeres.10       0
# Varones.11       0
# Mujeres.11       0
# Varones.12       0
# Mujeres.12       0
# Varones.13       0
# Mujeres.13       0
# Varones.14       0
# Mujeres.14       0
# Varones.15       0
# Mujeres.15       0
# Varones.16       0
# Mujeres.16       0
# Varones.17       0
# Mujeres.17       0
# Varones.18       0
# Mujeres.18       0
# Varones.19       0
# Mujeres.19       0
# Varones.20       0
# Mujeres.20       0
# Varones.21       0
# Mujeres.21       0
# ...

# %%
df_matriculados_primario_segun_genero.head()
# Out:
#      Departamentos  Varones  Mujeres  Varones.1  Mujeres.1  Varones.2  \
# 0  Total Provincia   185693   179664     187747     181229     188894
# 1      Calamuchita     2714     2640       2803       2626       2791
# 2          Capital    75438    73848      76251      74092      76438
# 3            Col�n    10951    10459      11383      10982      12124
# 4     Cruz del Eje     3749     3612       3774       3674       3857
#
#    Mujeres.2  Varones.3  Mujeres.3  Varones.4  ...  Varones.19  Mujeres.19  \
# 0     182222     188063     180794     188714  ...      181942      174719
# 1       2648       2696       2679       2813  ...        3524        3212
# 2      74515      76472      74192      76230  ...       72214       69918
# 3      11449      12152      11587      12443  ...       14246       13632
# 4       3689       3915       3741       4069  ...        3322        3148
#
#    Varones.20  Mujeres.20  Varones.21  Mujeres.21  Varones.22  Mujeres.22  \
# ...

# %%
# Seleccionar fila Dpto.Totoral

alumnos_inscritos_dpto_totoral= df_matriculados_primario_segun_genero.iloc[24]

alumnos_inscritos_dpto_totoral
# Out:
# Departamentos    Totoral
# Varones             1104
# Mujeres             1084
# Varones.1           1118
# Mujeres.1           1075
# Varones.2           1099
# Mujeres.2           1074
# Varones.3           1104
# Mujeres.3           1067
# Varones.4           1136
# Mujeres.4           1117
# Varones.5           1137
# Mujeres.5           1092
# Varones.6           1128
# Mujeres.6           1085
# Varones.7           1121
# Mujeres.7           1078
# Varones.8           1142
# Mujeres.8           1037
# Varones.9           1129
# Mujeres.9           1033
# Varones.10          1095
# Mujeres.10          1009
# Varones.11          1086
# Mujeres.11          1016
# Varones.12          1132
# Mujeres.12          1027
# Varones.13          1122
# Mujeres.13          1029
# Varones.14          1087
# Mujeres.14          1033
# Varones.15          1058
# Mujeres.15          1027
# Varones.16          1046
# Mujeres.16          1032
# Varones.17           993
# Mujeres.17          1016
# ...

# %%
#Crear Dataframe para alumnos inscritos en escuelas primarias del Dpto. Totoral según su género.
df_matriculados_primario_segun_genero_dpto_totoral= pd.DataFrame(alumnos_inscritos_dpto_totoral)

df_matriculados_primario_segun_genero_dpto_totoral.T
# Out:
#    Departamentos Varones Mujeres Varones.1 Mujeres.1 Varones.2 Mujeres.2  \
# 24       Totoral    1104    1084      1118      1075      1099      1074
#
#    Varones.3 Mujeres.3 Varones.4  ... Varones.19 Mujeres.19 Varones.20  \
# 24      1104      1067      1136  ...        986       1001       1010
#
#    Mujeres.20 Varones.21 Mujeres.21 Varones.22 Mujeres.22 Varones.23  \
# 24       1025        998       1021        998        986       1013
#
#    Mujeres.23
# 24        999
#
# [1 rows x 49 columns]

# %%
# Datos proporcionados
cant_inscritos_segun_genero = [1104, 1084, 1118, 1075, 1099, 1074, 1104, 1067, 1136, 1117, 1137, 1092, 1128, 1085, 1121, 1078, 
                                1142, 1037, 1129, 1033, 1095, 1009, 1086, 1016, 1132, 1027, 1122, 1029, 1087, 1033, 1058, 1027, 
                                1046, 1032, 993, 1016, 991, 1017, 986, 1001, 1010, 1025, 998, 1021, 998, 986, 1013, 999]

# Años correspondientes a cada par de valores
years = list(range(1998, 1998 + len(cant_inscritos_segun_genero)//2))

# Asegurar que los datos tienen la longitud correcta
data = cant_inscritos_segun_genero[:len(years) * 2]

# Crear un array de índices para posicionar las barras
ind = np.arange(len(years))

# Configurar el tamaño de la figura
plt.figure(figsize=(15, 8))

# Crear gráfico de barras agrupado con colores mejorados
bar_width = 0.35
plt.bar(ind, data[::2], width=bar_width, label='Varones', color='#6fa4e5', edgecolor='skyblue')
plt.bar(ind + bar_width, data[1::2], width=bar_width, label='Mujeres', color='#f1908e', edgecolor='white')

# Configurar etiquetas y título
plt.xlabel('Año', fontweight='bold', fontsize=12)
plt.ylabel('Cantidad', fontweight='bold', fontsize=12)
plt.title('Cant de Varones y Mujeres inscritos en escuelas del Dpto. Totoral por Año - Nivel primario', fontweight='bold', fontsize=14)

# Agregar cantidades correspondientes a cada barra con etiquetas
for i, valor in enumerate(data[::2]):
    plt.text(ind[i], valor + 10, str(valor), ha='center', va='bottom', fontsize=10, fontweight='bold', color='#3498db')

for i, valor in enumerate(data[1::2]):
    plt.text(ind[i] + bar_width, valor + 10, str(valor), ha='center', va='bottom', fontsize=10, fontweight='bold', color='#e74c3c')

# Configurar posición de los ticks en el eje x
plt.xticks(ind + bar_width / 2, years)

# Mostrar la leyenda
plt.legend(title='Género', title_fontsize='12', loc='lower right')

# Mostrar el gráfico
plt.show()

promedio_inscritos_por_año= np.mean(cant_inscritos_segun_genero)

print(f'Promedio de alumnos inscritos en escuelas del Dpto. Totoral entre el periodo 1998- 2021: {promedio_inscritos_por_año}')
# Out:
# Promedio de alumnos inscritos en escuelas del Dpto. Totoral entre el periodo 1998- 2021: 1058.6041666666667

# %% [markdown]
# ##### “El gráfico ilustra la cantidad de alumnos, tanto varones como mujeres, inscritos en las escuelas del Departamento de Totoras durante el período analizado. Según los datos presentados, se puede observar una ligera tendencia a la baja en las inscripciones hasta llegar al año 2021. Además, se destaca una diferencia mínima entre el número de varones y mujeres inscritos.”

# %%
# Crear Dataframe para alumnos repitentes de primaria en la Provincia de Cba.

df_alumnos_repitentes_primario= pd.DataFrame(leer_archivo_repitentes_primaria)

df_alumnos_repitentes_primario
# Out:
#                    Departamento  1998  1999  2000  2001  2002 2003 2004 2005  \
# 0               Total Provincia   5,8     6   5,8   5,3   4,3    4  4,1  4,1
# 1                   Calamuchita   7,5   8,3   7,2   6,5   5,3  4,4    6  5,5
# 2                       Capital   5,7     6   5,7     5   3,8  3,6  3,4  3,7
# 3                         Col�n   7,4   8,1   7,1   7,4   6,3  5,9  5,1  5,2
# 4                  Cruz del Eje   9,1   8,4   7,4     8   7,5  6,6  6,9  3,6
# 5                  General Roca   8,1   7,5     8   6,3   5,5  5,8  7,1  6,3
# 6            General San Mart�n     4     4   3,9   3,8   2,8  2,7  2,8  2,7
# 7                      Ischil�n   7,6     8   7,5     7   6,3  6,5  6,2  6,4
# 8                 Ju�rez Celman   4,5   4,2   4,2   4,8   2,7  2,8  4,1  3,2
# 9                 Marcos Ju�rez   3,4   3,8   3,7   2,8   2,5  2,4  2,5  3,1
# 10                        Minas  10,5   9,6   7,5   4,3   3,5  4,4  2,8  4,2
# ...

# %%
df_alumnos_repitentes_primario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Departamento  27 non-null     object
#  1   1998          27 non-null     object
#  2   1999          27 non-null     object
#  3   2000          27 non-null     object
#  4   2001          27 non-null     object
#  5   2002          27 non-null     object
#  6   2003          27 non-null     object
#  7   2004          27 non-null     object
#  8   2005          27 non-null     object
#  9   2006          27 non-null     object
#  10  2007          27 non-null     object
#  11  2008          27 non-null     object
#  12  2009          27 non-null     object
#  13  2010          27 non-null     object
#  14  2011          27 non-null     object
#  15  2012          27 non-null     object
#  16  2013          27 non-null     object
#  17  2014          27 non-null     object
# ...

# %%
print(f'Total de valores nulos encontrados: {df_alumnos_repitentes_primario.isnull().sum()}')

print(f'\n Total de valores duplicados encontrados: {df_alumnos_repitentes_primario.duplicated().sum()}')
# Out:
# Total de valores nulos encontrados: Departamento    0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64
#
#  Total de valores duplicados encontrados: 0

# %%
#Seleccionar fila para Dpto. Totoral
df_alumnos_repitentes_primario_dpto_totoral= df_alumnos_repitentes_primario.iloc[24]

df_alumnos_repitentes_primario_dpto_totoral
# Out:
# Departamento    Totoral
# 1998               11,9
# 1999               11,6
# 2000               13,3
# 2001               11,2
# 2002               11,1
# 2003                6,9
# 2004                7,3
# 2005                8,5
# 2006                7,6
# 2007                4,3
# 2008                7,6
# 2009                6,4
# 2010                6,4
# 2011                  2
# 2012                2,2
# 2013                  2
# 2014                1,5
# 2015                0,3
# 2016                0,9
# 2017                1,1
# 2018                0,5
# 2019                0,1
# 2020                0,3
# 2021                0,9
# Name: 24, dtype: object

# %%
df_alumnos_repitentes_totoral= pd.DataFrame(df_alumnos_repitentes_primario_dpto_totoral)

df_alumnos_repitentes_totoral.T
# Out:
#    Departamento  1998  1999  2000  2001  2002 2003 2004 2005 2006  ... 2012  \
# 24      Totoral  11,9  11,6  13,3  11,2  11,1  6,9  7,3  8,5  7,6  ...  2,2
#
#    2013 2014 2015 2016 2017 2018 2019 2020 2021
# 24    2  1,5  0,3  0,9  1,1  0,5  0,1  0,3  0,9
#
# [1 rows x 25 columns]

# %%
# Datos correspondientes al porcentaje de alumnos repitentes del nivel primario en el Dpto. Totoral
data = {
    'Año': list(range(1998, 2022)),
    'Totoral': [11.9, 11.6, 13.3, 11.2, 11.1, 6.9, 7.3, 8.5, 7.6, 4.3, 7.6, 6.4, 6.4, 2, 2.2, 2, 1.5, 0.3, 0.9, 1.1, 0.5, 0.1, 0.3, 0.9]
}


nuevo_df = pd.DataFrame(data)

# Configurar el estilo de Seaborn para mejorar la estética
sns.set(style="whitegrid", rc={"grid.linestyle": '--'})

# Configurar el tamaño de la figura y la resolución
fig, ax = plt.subplots(figsize=(12, 9), dpi=80)

# Crear el gráfico de barras
bars = ax.bar(nuevo_df['Año'], nuevo_df['Totoral'], color='skyblue', edgecolor='grey', linewidth=1)

# Añadir etiquetas y título
plt.title('Índice de Repitencia por año para escuelas del Dpto. Totoral - Nivel Primario', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Año', fontsize=14, color='#555555')
plt.ylabel('Porcentaje de Repitencia (%)', fontsize=14, color='#555555')
plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')

# Añadir etiquetas en las barras con valores en porcentajes
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{round(yval, 2)}%', ha='center', va='bottom', fontsize=10, color='#555555')

# Añadir una leyenda
plt.legend(['Repitencia'], loc='upper right', fontsize=12)

# Añadir una rejilla para mejor lectura
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Eliminar bordes innecesarios
sns.despine()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### “El gráfico anterior evidencia una disminución drástica en el porcentaje de alumnos que repiten el año en el Departamento de Totoral a partir del año 2001. Este descenso no solo transmite un mensaje positivo con respecto a la tasa de repetición, sino que también proporciona un contexto para reflexionar, especialmente considerando que el país estaba atravesando una crisis socioeconómica en ese momento.”

# %%
#Crear Dataframe para alumnos con sobredad en escuelas primarias de la Prov. de Córdoba

df_alumnos_con_sobredad= pd.DataFrame(leer_archivo_sobredad_primaria)

df_alumnos_con_sobredad
# Out:
#                    Departamento  1998  1999  2000  2001  2002  2003  2004  \
# 0               Total Provincia  18,3  18,5  18,9    20  19,2  19,3  18,1
# 1                   Calamuchita  24,2  20,9  21,1  22,7  22,7  23,4  21,6
# 2                       Capital  17,1  17,7  17,8  19,8  18,2  18,4  16,9
# 3                         Col�n  25,7  22,6  23,8  22,8  23,6  23,6  22,9
# 4                  Cruz del Eje  31,7  27,7  26,3  31,1  29,1  27,1  26,4
# 5                  General Roca  21,7  22,5  22,4  25,8  22,3  24,1  21,2
# 6            General San Mart�n  15,4  14,2  13,6  14,6  14,2  17,4  13,4
# 7                      Ischil�n  22,3  29,3    25  25,3  24,2  26,4  24,5
# 8                 Ju�rez Celman  16,1  14,6  14,1  15,8  16,2    17  17,9
# 9                 Marcos Ju�rez  13,1  13,8  13,2  13,9  14,9  14,2  13,1
# 10                        Minas  25,5  30,5  25,9  35,5  24,4  29,4  21,3
# 11                        Pocho  20,5    19  20,6  21,1  20,9  23,4  26,2
# ...

# %%
print(f'Total de valores nulos encontrados: {df_alumnos_con_sobredad.isnull().sum()}')

print(f'\n Total de valores duplicados encontrados: {df_alumnos_con_sobredad.duplicated().sum()}')
# Out:
# Total de valores nulos encontrados: Departamento    0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64
#
#  Total de valores duplicados encontrados: 0

# %%
df_alumnos_con_sobredad.head()
# Out:
#       Departamento  1998  1999  2000  2001  2002  2003  2004  2005  2006  ...  \
# 0  Total Provincia  18,3  18,5  18,9    20  19,2  19,3  18,1  17,2    15  ...
# 1      Calamuchita  24,2  20,9  21,1  22,7  22,7  23,4  21,6    25  16,4  ...
# 2          Capital  17,1  17,7  17,8  19,8  18,2  18,4  16,9  15,6  13,7  ...
# 3            Col�n  25,7  22,6  23,8  22,8  23,6  23,6  22,9  19,2  17,5  ...
# 4     Cruz del Eje  31,7  27,7  26,3  31,1  29,1  27,1  26,4  25,2  25,7  ...
#
#    2012  2013  2014  2015 2016 2017 2018 2019 2020 2021
# 0  14,1  12,2   9,8   7,7  6,2  4,8  3,8  2,9  2,6  2,2
# 1    21  17,9  12,8  10,5    8  5,9  4,5  4,2  3,6  1,9
# 2  13,2  11,2   9,1   7,3  6,4  5,1  3,9  2,9  2,9  2,5
# 3  15,6  14,4  11,8   9,6  7,7  6,4  6,3  4,8  4,7  3,8
# 4    19  16,1  13,7   9,8  7,8  5,9  4,4  3,7    3  2,7
#
# [5 rows x 25 columns]

# %%
# Seleccionar fila para Dpto. Totoral
df_alumnos_con_sobredad_dpto_totoral= df_alumnos_con_sobredad.iloc[24]

df_alumnos_con_sobredad_totoral= pd.DataFrame(alumnos_inscritos_dpto_totoral)

# %%
df_alumnos_con_sobredad_totoral.T
# Out:
#    Departamentos Varones Mujeres Varones.1 Mujeres.1 Varones.2 Mujeres.2  \
# 24       Totoral    1104    1084      1118      1075      1099      1074
#
#    Varones.3 Mujeres.3 Varones.4  ... Varones.19 Mujeres.19 Varones.20  \
# 24      1104      1067      1136  ...        986       1001       1010
#
#    Mujeres.20 Varones.21 Mujeres.21 Varones.22 Mujeres.22 Varones.23  \
# 24       1025        998       1021        998        986       1013
#
#    Mujeres.23
# 24        999
#
# [1 rows x 49 columns]

# %%
# Datos proporcionados
porcentaje = [333, 307, 332, 299, 297, 291, 289, 263, 218, 232, 234, 221, 227, 224, 177, 16, 115, 101, 64, 49, 33, 24, 32, 24]
años = [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# Ajustar el porcentaje dividiendo cada valor por 10
porcentaje_ajustado = [p / 10 for p in porcentaje]

# Establecer el estilo de seaborn para una apariencia más moderna
sns.set(style="whitegrid")

# Crear el gráfico con Matplotlib
plt.figure(figsize=(12, 6))
sns.lineplot(x=años, y=porcentaje_ajustado, marker='o', color='#3498db', linewidth=2)

# Añadir etiquetas y título
plt.xlabel('Año', fontsize=14, fontweight='bold')
plt.ylabel('Porcentaje de alumnos con sobreedad (%)', fontsize=14, fontweight='bold')
plt.title('Indice de sobredad por año para escuelas del Dpto. Totoral - Nivel primario', fontsize=16, fontweight='bold')

# Añadir etiquetas a los puntos de datos

# Ajustes adicionalesfor i, txt in enumerate(porcentaje_ajustado):
for i, txt in enumerate(porcentaje_ajustado):
    plt.annotate(f'{txt:.1f}%', (años[i], porcentaje_ajustado[i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=10, color='#333333')

plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Ajustar la escala del eje y para mayor legibilidad
plt.ylim(0, max(porcentaje_ajustado) + 5)

# Mostrar el gráfico
plt.legend(['% Sobredad por año'], loc='upper right', fontsize=12)

plt.tight_layout()
plt.show()
porcentaje_por_anios= np.mean(porcentaje_ajustado)

print(f'Promedio anual de alumnos de primaria con sobreedad en el Dpto Totoral: {porcentaje_por_anios} %')
# Out:
# Promedio anual de alumnos de primaria con sobreedad en el Dpto Totoral: 18.341666666666665 %

# %% [markdown]
# #### "El gráfico anterior ilustra la tendencia anual en porcentajes de los alumnos de escuelas primarias con sobreedad en el Departamento Totoral. Se observa una fuerte correlación entre esta tendencia y la de los alumnos repetidores. Notablemente, se muestra una reducción sustancial tanto en el índice de sobreedad como en el de repetidores entre los alumnos de Primaria. Este patrón sugiere mejoras significativas en estos aspectos a lo largo de los años."

# %% [markdown]
# ### Procesamiento de datos para escuelas del Nivel secundario
# ---

# %%
# Lectura de archivos CSV para Nivel secundario
leer_archivo_matriculados_secundario= pd.read_csv("datos-nivel-secundario/alumnos_matriculados_secundario_1998-2021.csv",sep=';')

leer_archivo_matriculados_secundario_segun_genero= pd.read_csv("datos-nivel-secundario/alumnos_matriculados_secundario_segun_genero_2006-2021.csv",sep=';')

leer_archivo_repitentes_secundario= pd.read_csv("datos-nivel-secundario/alumnos_repitentes_secundario_2000-2021.csv",sep=';')

leer_archivo_repitentes_secundario_segun_genero= pd.read_csv("datos-nivel-secundario/alumnos_repitentes_secundario_segun_genero_2000-2021.csv",sep=';')

leer_archivo_sobredad_secundario= pd.read_csv("datos-nivel-secundario/alumnos_con_sobredad_secundario_1998-2021.csv",sep=';')

# %%
#Crear Dataframe para alumnos matriculados en la Prov. de Córdoba

df_alumnos_matriculados_secundario= pd.DataFrame(leer_archivo_matriculados_secundario)

df_alumnos_matriculados_secundario
# Out:
#                    Departamento    1998    1999    2000    2001    2002  \
# 0               Total Provincia  264579  262073  262199  268141  275367
# 1                   Calamuchita    3371    3445    3461    3628    3816
# 2                       Capital  114522  112021  110978  112669  114849
# 3                         Col�n   13027   13705   14052   14614   15409
# 4                  Cruz del Eje    4903    4897    4913    5022    5188
# 5                  General Roca    2882    2881    2846    2885    2953
# 6            General San Mart�n   10397   10267   10236   10409   10671
# 7                      Ischil�n    2756    2668    2662    2655    2645
# 8                 Ju�rez Celman    4760    4830    4770    5059    5190
# 9                 Marcos Ju�rez    8575    8398    8195    8366    8618
# 10                        Minas     290     268     287     293     325
# 11                        Pocho     339     285     299     361     396
# ...

# %%
print(f'Total de valores nulos encontrados: {df_alumnos_matriculados_secundario.isnull().sum()}')

print(f'\n Total de valores duplicados encontrados: {df_alumnos_matriculados_secundario.duplicated().sum()}')
# Out:
# Total de valores nulos encontrados: Departamento    0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64
#
#  Total de valores duplicados encontrados: 0

# %% [markdown]
# ##### Según el padrón de Escuelas (2023), el Departamento Totoral cuenta con 13 Escuelas secundarias Común y tecnicas de Gestión Estatal.
# ##### Fuente: https://www.cba.gov.ar/padron-de-escuelas-provinciales-educacion/

# %%
# Seleccionar fila Dpto. Totoral
df_alumnos_matriculados_secundario_dpto_totoral= df_alumnos_matriculados_secundario.iloc[24]

df_alumnos_matriculados_secundario_dpto_totoral
# Out:
# Departamento    Totoral
# 1998               1131
# 1999               1130
# 2000               1204
# 2001               1231
# 2002               1235
# 2003               1297
# 2004               1300
# 2005               1340
# 2006               1432
# 2007               1477
# 2008               1429
# 2009               1599
# 2010               1626
# 2011               1713
# 2012               1664
# 2013               1695
# 2014               1705
# 2015               1795
# 2016               1787
# 2017               1837
# 2018               1862
# 2019               1977
# 2020               1997
# 2021               2054
# Name: 24, dtype: object

# %%
# Crear Dataframe para alumnos matriculados de esceulas sencundarias en el Dpto. Totoral

df_alumnos_matriculados_secundario_totoral= pd.DataFrame(df_alumnos_matriculados_secundario_dpto_totoral)

df_alumnos_matriculados_secundario_totoral.T
# Out:
#    Departamento  1998  1999  2000  2001  2002  2003  2004  2005  2006  ...  \
# 24      Totoral  1131  1130  1204  1231  1235  1297  1300  1340  1432  ...
#
#     2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 24  1664  1695  1705  1795  1787  1837  1862  1977  1997  2054
#
# [1 rows x 25 columns]

# %%
cant_alumnos_secundario= [1131, 1130, 1204, 1231, 1235, 1297, 1300, 1340, 1432, 1477, 1429, 1599, 1626, 1713, 
                          1664, 1695, 1705, 1795, 1787, 1837, 1862, 1977, 1997, 2054]

cant_alumnos_año = [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 
                    2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Estilo de Seaborn para mejorar la estética
sns.set(style="whitegrid", rc={"grid.linestyle": '--'})

# Tamaño de la figura y la resolución
fig, ax = plt.subplots(figsize=(12, 8), dpi=80)

# Crear el gráfico de líneas
line = sns.lineplot(x=cant_alumnos_año, y=cant_alumnos_secundario, marker='o', color='orange', linewidth=2, label='Alumnos inscritos por año')

# Añadir etiquetas y título
plt.xlabel('Año - periodo', fontsize=14, fontweight='bold', color='#555555')
plt.ylabel('Cantidad de alumnos Inscritos', fontsize=14, fontweight='bold', color='#555555')
plt.title('Cant de alumnos Inscritos por año en el Dpto Totoral -  Nivel secundario', fontsize=16, fontweight='bold', color='#555555')

# Añadir etiquetas a los puntos de datos
for i, txt in enumerate(cant_alumnos_secundario):
    plt.annotate(txt, (cant_alumnos_año[i], cant_alumnos_secundario[i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=10, color='#333333')


# Añadir una rejilla para mejor lectura
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Eliminar bordes innecesarios
plt.box(False)

# Agregar color de fondo
ax.set_facecolor('#f3f3f3')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

promedio_inscritos= np.mean(cant_alumnos_secundario)

print(f'Promedio de alumnos inscritos en escuelas secundarias del Dpto. Totoral entre el periodo 1998 - 2021: {promedio_inscritos}')
# Out:
# Promedio de alumnos inscritos en escuelas secundarias del Dpto. Totoral entre el periodo 1998 - 2021: 1563.2083333333333

# %% [markdown]
# #### “El gráfico anterior representa la evolución de las inscripciones de alumnos para el nivel secundario desde 1998 hasta 2021. La línea de tendencia muestra un crecimiento constante, con un leve retroceso alrededor del año 2008. Este patrón indica un aumento general en las inscripciones a lo largo de los años, a pesar de la pequeña disminución en 2008.”

# %%
#Crear Dataframe para alumnos matriculados segun su genero en la Prov. de Córdoba

df_alumnos_matriculados_secundario_segun_genero= pd.DataFrame(leer_archivo_matriculados_secundario_segun_genero)

df_alumnos_matriculados_secundario_segun_genero
# Out:
#                    Departamento  Varones  Mujeres  Varones.1  Mujeres.1  \
# 0               Total Provincia   138249   148574     137628     149260
# 1                   Calamuchita     1996     2229       1991       2227
# 2                       Capital    58350    61474      57550      61216
# 3                         Col�n     8511     9251       8644       9492
# 4                  Cruz del Eje     2816     2915       2816       2916
# 5                  General Roca     1416     1600       1395       1545
# 6            General San Mart�n     5197     5618       5262       5793
# 7                      Ischil�n     1470     1558       1397       1571
# 8                 Ju�rez Celman     2639     2734       2657       2715
# 9                 Marcos Ju�rez     4017     4327       4045       4326
# 10                        Minas      203      207        194        247
# 11                        Pocho      195      192        188        199
# ...

# %%
print(f'Total de valores nulos encontrados: {df_alumnos_matriculados_secundario_segun_genero.isnull().sum()}')

print(f'\n Total de valores duplicados encontrados: {df_alumnos_matriculados_secundario_segun_genero.duplicated().sum()}')
# Out:
# Total de valores nulos encontrados: Departamento    0
# Varones         0
# Mujeres         0
# Varones.1       0
# Mujeres.1       0
# Varones.2       0
# Mujeres.2       0
# Varones.3       0
# Mujeres.3       0
# Varones.4       0
# Mujeres.4       0
# Varones.5       0
# Mujeres.5       0
# Varones.6       0
# Mujeres.6       0
# Varones.7       0
# Mujeres.7       0
# Varones.8       0
# Mujeres.8       0
# Varones.9       0
# Mujeres.9       0
# Varones.10      0
# Mujeres.10      0
# Varones.11      0
# Mujeres.11      0
# Varones.12      0
# Mujeres.12      0
# Varones.13      0
# Mujeres.13      0
# Varones.14      0
# Mujeres.14      0
# Varones.15      0
# Mujeres.15      0
# dtype: int64
#
#  Total de valores duplicados encontrados: 0

# %%
# Seleccionar fila Dpto. Totoral
df_alumnos_matriculados_secundario_segun_genero_dpto_totoral= df_alumnos_matriculados_secundario_segun_genero.iloc[24]

df_alumnos_matriculados_secundario_segun_genero_dpto_totoral
# Out:
# Departamento    Totoral
# Varones             714
# Mujeres             718
# Varones.1           738
# Mujeres.1           739
# Varones.2           682
# Mujeres.2           747
# Varones.3           822
# Mujeres.3           777
# Varones.4           803
# Mujeres.4           823
# Varones.5           857
# Mujeres.5           856
# Varones.6           831
# Mujeres.6           833
# Varones.7           859
# Mujeres.7           836
# Varones.8           861
# Mujeres.8           844
# Varones.9           907
# Mujeres.9           888
# Varones.10          885
# Mujeres.10          902
# Varones.11          926
# Mujeres.11          911
# Varones.12          921
# Mujeres.12          941
# Varones.13          990
# Mujeres.13          987
# Varones.14         1000
# Mujeres.14          997
# Varones.15         1006
# Mujeres.15         1048
# Name: 24, dtype: object

# %%
#Crear Dataframe para alumnos matriculados segun genero para escuelas secundarias del Dpto. Totoral

df_alumnos_matriculados_secundario_segun_genero_totoral= pd.DataFrame(df_alumnos_matriculados_secundario_segun_genero_dpto_totoral)

df_alumnos_matriculados_secundario_segun_genero_totoral.T
# Out:
#    Departamento Varones Mujeres Varones.1 Mujeres.1 Varones.2 Mujeres.2  \
# 24      Totoral     714     718       738       739       682       747
#
#    Varones.3 Mujeres.3 Varones.4  ... Varones.11 Mujeres.11 Varones.12  \
# 24       822       777       803  ...        926        911        921
#
#    Mujeres.12 Varones.13 Mujeres.13 Varones.14 Mujeres.14 Varones.15  \
# 24        941        990        987       1000        997       1006
#
#    Mujeres.15
# 24       1048
#
# [1 rows x 33 columns]

# %%
Cant_inscritos_secundario=[714, 718, 738, 739, 682, 747, 822, 777, 803, 823, 857, 856, 831, 833, 859, 836, 861, 
                           844, 907, 888, 885, 902, 926, 911, 921, 941, 990, 987, 1000, 997, 1006, 1048]

# Años correspondientes a cada par de valores
years = list(range(2006, 2006 + len(Cant_inscritos_secundario)//2))

# Asegurar que los datos tienen la longitud correcta
data = Cant_inscritos_secundario[:len(years) * 2]

# Crear un array de índices para posicionar las barras
ind = np.arange(len(years))

# Configurar el tamaño de la figura
plt.figure(figsize=(15, 8))

# Crear gráfico de barras agrupado con colores mejorados
bar_width = 0.35
plt.bar(ind, data[::2], width=bar_width, label='Varones', color='Skyblue', edgecolor='grey')
plt.bar(ind + bar_width, data[1::2], width=bar_width, label='Mujeres', color='Pink', edgecolor='grey')

# Configurar etiquetas y título
plt.xlabel('Año - Periodo', fontweight='bold', fontsize=12)
plt.ylabel('Cantidad de alumnos inscritos', fontweight='bold', fontsize=12)
plt.title('Cant de Varones y Mujeres inscritos en escuelas del Dpto. Totoral por Año - Nivel secundario', fontweight='bold', fontsize=14)

# Agregar cantidades correspondientes a cada barra con etiquetas
for i, valor in enumerate(data[::2]):
    plt.text(ind[i], valor + 10, str(valor), ha='center', va='bottom', fontsize=10, fontweight='bold', color='#555555')

for i, valor in enumerate(data[1::2]):
    plt.text(ind[i] + bar_width, valor + 10, str(valor), ha='center', va='bottom', fontsize=10, fontweight='bold', color='#555555')

# Configurar posición de los ticks en el eje x
plt.xticks(ind + bar_width / 2, years)

# Mostrar la leyenda
plt.legend(title='Género', title_fontsize='12', loc='upper left')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ##### “El gráfico superior muestra la cantidad de alumnos inscritos en escuelas secundarias en el Departamento Totoral, desglosados por género. Se puede observar una pequeña disparidad en el número de alumnos inscritos según su género. Además, a partir del año 2009, se visualiza una tendencia ascendente en las inscripciones.”

# %%
df_alumnos_repitentes_secundario= pd.DataFrame(leer_archivo_repitentes_secundario)

df_alumnos_repitentes_secundario
# Out:
#              Departamento  1998  1999  2000  2001  2002  2003  2004  2005  \
# 0         Total Provincia  10,1   9,7   9,2   8,5   8,1   8,7   9,4  10,1
# 1             Calamuchita  10,5  10,7   9,5   8,7   7,9  11,7     8  11,1
# 2                 Capital  10,3   9,7   8,8   8,4   8,1   8,6   9,3   9,7
# 3                   Col�n  10,8   9,4   9,1   7,8   6,7   7,1   8,1  10,2
# 4            Cruz del Eje  12,1  12,6  12,7   9,1   9,7  10,7  11,8   7,4
# 5            General Roca   7,2   7,4   9,1   8,4   6,8     8   8,9   8,2
# 6      General San Martin   9,1   9,4   8,7   8,4   9,1  10,3   8,9    11
# 7                Ischil�n  18,2  19,7  17,9  18,6  14,9  14,6  14,9  17,8
# 8           Ju�rez Celman    10  10,6   8,9   9,2  10,1   7,9    10  10,4
# 9           Marcos Ju�rez   8,8     8   8,3   7,4     8   8,9   8,8   9,1
# 10                  Minas  12,1  14,9  12,9   9,9   7,4  10,9   9,6   7,3
# 11                  Pocho   8,3   7,7     5  10,5  11,1   9,9   8,4   7,9
# ...

# %%
print(f'Total de valores nulos encontrados: {df_alumnos_repitentes_secundario.isnull().sum()}')

print(f'\n Total de valores duplicados encontrados: {df_alumnos_repitentes_secundario.duplicated().sum()}')
# Out:
# Total de valores nulos encontrados: Departamento    0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64
#
#  Total de valores duplicados encontrados: 0

# %%
df_alumnos_repitentes_secundario_dpto_totoral= df_alumnos_repitentes_secundario.iloc[24]

df_alumnos_repitentes_secundario_dpto_totoral
# Out:
# Departamento    Totoral
# 1998               15,6
# 1999                9,3
# 2000               19,9
# 2001                9,9
# 2002                9,1
# 2003                8,9
# 2004                7,6
# 2005                9,3
# 2006               11,5
# 2007               10,7
# 2008               12,7
# 2009                9,8
# 2010                7,7
# 2011                 11
# 2012               12,2
# 2013                 12
# 2014               13,1
# 2015               10,5
# 2016                9,6
# 2017               10,1
# 2018               10,8
# 2019                8,8
# 2020                7,6
# 2021                6,2
# Name: 24, dtype: object

# %%
df_alumnos_repitentes_secundario_totoral= pd.DataFrame(df_alumnos_repitentes_secundario_dpto_totoral)

df_alumnos_repitentes_secundario_totoral.T
# Out:
#    Departamento  1998 1999  2000 2001 2002 2003 2004 2005  2006  ...  2012  \
# 24      Totoral  15,6  9,3  19,9  9,9  9,1  8,9  7,6  9,3  11,5  ...  12,2
#
#    2013  2014  2015 2016  2017  2018 2019 2020 2021
# 24   12  13,1  10,5  9,6  10,1  10,8  8,8  7,6  6,2
#
# [1 rows x 25 columns]

# %%
# Datos correspondientes al porcentaje de alumnos repitentes por año para el Dpto. Totoral
porcentaje_repitentes_por_anio= {'Año': list(range(1998, 2022)),
'porcentaje_alumnos_repitentes':[15.6, 9.3, 19.9, 9.9, 9.1, 8.9, 7.6, 9.3, 11.5, 10.7, 12.7, 9.8, 7.7, 11, 12.2, 12, 
                                13.1, 10.5, 9.6, 10.1, 10.8, 8.8, 7.6, 6.2]
                                }

df_ = pd.DataFrame(porcentaje_repitentes_por_anio)

# Configurar el estilo de Seaborn para mejorar la estética
sns.set(style="whitegrid", rc={"grid.linestyle": '--'})

# Configurar el tamaño de la figura y la resolución
fig, ax = plt.subplots(figsize=(12, 9), dpi=80)

# Crear el gráfico de barras
bars = ax.bar(df_['Año'], df_['porcentaje_alumnos_repitentes'], color='orange', edgecolor='grey', linewidth=1)

# Añadir etiquetas y título
plt.title('Índice de Repitencia por año para escuelas del Dpto. Totoral - Nivel secundario', fontsize=16, fontweight='bold', color='#333333')
plt.xlabel('Año', fontsize=14, color='#555555')
plt.ylabel('Porcentaje de Repitencia (%)', fontsize=14, color='#555555')
plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')

# Añadir etiquetas en las barras con valores en porcentajes
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{round(yval, 2)}%', ha='center', va='bottom', fontsize=10, color='#555555')

# Añadir una leyenda
plt.legend(['Repitencia'], loc='upper right', fontsize=12)

# Añadir una rejilla para mejor lectura
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Eliminar bordes innecesarios
sns.despine()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### “El gráfico superior ilustra el comportamiento de los alumnos repetidores de escuelas secundarias en el Departamento Totoral. Se observa una reducción drástica en el número de repetidores en el año 1999, seguida de un fuerte aumento en el año 2000. Posteriormente, la tasa de repetición se redujo notablemente en el año 2001. Desde entonces y hasta el año 2021, la tasa de repetición se ha mantenido en un canal paralelo sin mayores cambios para el periodo comprendido.”

# %%
# Crear Dataframe para alumnos con sobreedad en la Prov. de Córdoba
df_alumnos_con_sobredad_secundario= pd.DataFrame(leer_archivo_sobredad_secundario)

df_alumnos_con_sobredad_secundario
# Out:
#                    Departamento  1998  1999  2000  2001  2002  2003  2004  \
# 0               Total Provincia  31,7  31,5    32  32,6  32,4  31,1  30,4
# 1                   Calamuchita  30,2  36,1  30,9    33  30,3  28,4  32,4
# 2                       Capital  33,5    33  33,5  34,1    34  33,4  31,7
# 3                         Col�n  33,4  33,9  32,7    33  34,5  31,5  30,4
# 4                  Cruz del Eje  39,6  40,3  40,4  40,6  42,4  37,8  38,7
# 5                  General Roca  24,6  25,2  23,8  27,5  25,5  23,4  26,3
# 6            General San Mart�n  30,5  28,6  28,7  27,4  27,7    26  28,8
# 7                      Ischil�n  46,6    52  52,3    51  49,6  41,3    39
# 8                 Ju�rez Celman  28,1  26,4  27,5  26,7  32,4  30,1  32,7
# 9                 Marcos Ju�rez    24  22,5  22,6  23,7    30  26,1  21,5
# 10                        Minas  44,8  40,7  42,9  39,3  42,2    35  34,4
# 11                        Pocho    46  33,7  35,1  58,5  41,9  38,8  33,4
# ...

# %%
print(f'Total de valores nulos encontrados: {df_alumnos_con_sobredad_secundario.isnull().sum()}')

print(f'\n Total de valores duplicados encontrados: {df_alumnos_con_sobredad_secundario.duplicated().sum()}')
# Out:
# Total de valores nulos encontrados: Departamento    0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64
#
#  Total de valores duplicados encontrados: 0

# %%
df_alumnos_con_sobredad_secundario.head()
# Out:
#       Departamento  1998  1999  2000  2001  2002  2003  2004  2005  2006  ...  \
# 0  Total Provincia  31,7  31,5    32  32,6  32,4  31,1  30,4  30,3  28,8  ...
# 1      Calamuchita  30,2  36,1  30,9    33  30,3  28,4  32,4  32,3  27,9  ...
# 2          Capital  33,5    33  33,5  34,1    34  33,4  31,7  31,7  29,5  ...
# 3            Col�n  33,4  33,9  32,7    33  34,5  31,5  30,4  30,9  30,1  ...
# 4     Cruz del Eje  39,6  40,3  40,4  40,6  42,4  37,8  38,7  37,2  36,1  ...
#
#    2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0  32,9  30,1  28,8  27,8  26,8    25  24,2    23  22,4  21,3
# 1  31,9  31,2  29,4  26,4  28,4  26,3    25  24,4    24    23
# 2  33,7  31,6    30  29,5  28,5  26,5  25,6  24,5    24  23,3
# 3  34,9  30,5    29  26,6  27,2  24,8  24,7  23,7  22,9  20,3
# 4    40  33,9  34,8  32,3  30,4  28,9  29,2  24,9  22,9  24,5
#
# [5 rows x 25 columns]

# %%
secundario_con_sobredad_dpto_totoral= df_alumnos_con_sobredad_secundario.iloc[24]

secundario_con_sobredad_dpto_totoral
# Out:
# Departamento    Totoral
# 1998               36,3
# 1999               46,7
# 2000               45,2
# 2001               45,5
# 2002               44,5
# 2003               47,4
# 2004               36,9
# 2005               37,1
# 2006               33,4
# 2007               35,1
# 2008               35,8
# 2009               40,5
# 2010               40,2
# 2011               34,4
# 2012               34,8
# 2013               37,2
# 2014               35,8
# 2015               35,5
# 2016               31,3
# 2017               28,4
# 2018               25,5
# 2019               27,1
# 2020               26,6
# 2021               24,8
# Name: 24, dtype: object

# %%
# Crear Dataframe para alumnos con sobre edad en escuelas secundarias del Dpto. Totoral
df_alumnos_con_sobredad_dpto_totoral= pd.DataFrame(secundario_con_sobredad_dpto_totoral)

df_alumnos_con_sobredad_dpto_totoral.T
# Out:
#    Departamento  1998  1999  2000  2001  2002  2003  2004  2005  2006  ...  \
# 24      Totoral  36,3  46,7  45,2  45,5  44,5  47,4  36,9  37,1  33,4  ...
#
#     2012  2013  2014  2015  2016  2017  2018  2019  2020  2021
# 24  34,8  37,2  35,8  35,5  31,3  28,4  25,5  27,1  26,6  24,8
#
# [1 rows x 25 columns]

# %%
porcentaje_sobredad_secundarios= [363,467,452,455,445,474,369,371,334,351,358,405,
                                   402,344,348,372,358,355,313,284,255,271,266,248]

anios = [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]


# Ajustar el porcentaje dividiendo cada valor por 10
porcentaje_ajust = [p / 10 for p in porcentaje_sobredad_secundarios]

# Establecer el estilo de seaborn para una apariencia más moderna
sns.set(style="whitegrid")

# Crear el gráfico con Matplotlib
plt.figure(figsize=(12, 6))
sns.lineplot(x=años, y=porcentaje_ajust, marker='o', color='violet', linewidth=2)

# Añadir etiquetas y título
plt.xlabel('Año', fontsize=14, fontweight='bold')
plt.ylabel('Porcentaje de alumnos con sobreedad (%)', fontsize=14, fontweight='bold')
plt.title('Indice de sobredad por año para escuelas del Dpto. Totoral - Nivel secundario', fontsize=16, fontweight='bold', color='#555555')

# Añadir etiquetas a los puntos de datos

# Ajustes adicionalesfor i, txt in enumerate(porcentaje_ajustado):
for i, txt in enumerate(porcentaje_ajust):
    plt.annotate(f'{txt:.1f}%', (anios[i], porcentaje_ajust[i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=10, color='#333333')

plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Ajustar la escala del eje y para mayor legibilidad
plt.ylim(0, max(porcentaje_ajust) + 5)

# Mostrar el gráfico
plt.legend(['% Sobredad por año'], loc='upper right', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### “En el gráfico superior, podemos apreciar el índice de sobredad para los alumnos de nivel secundario en las escuelas del Departamento Totoral. Desde 1998 hasta 2021, se observa una reducción del orden del 11,5% en el porcentaje correspondiente a este periodo. Además, en la serie intertemporal, se puede constatar que el porcentaje de alumnos con sobreedad no ha modificado su comportamiento de manera significativa.”
